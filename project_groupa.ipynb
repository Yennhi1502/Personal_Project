# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dfProduct = pd.read_csv('Product.csv')

# %%
dfRegion = pd.read_csv('Region.csv')

# %%
dfSale = pd.read_csv('Sales.csv')

# %%
dfSalesPerson = pd.read_csv('Salesperson.csv')

# %%
dfSalePersonRegion = pd.read_csv('SalespersonRegion.csv')

# %%
dfTarget = pd.read_csv('Targets.csv')

# %%
dfTarget['TargetMonth'] = pd.to_datetime(dfTarget['TargetMonth'])
dfTarget['TargetMonth']= dfTarget['TargetMonth'].dt.strftime('%d-%m-%Y')

# %%
dfTarget.head(5)
# Out:
#    EmployeeID  Target TargetMonth
# 0    90836195  500000  01-12-2017
# 1   112432117  500000  01-07-2017
# 2   139397894  500000  01-12-2017
# 3   191644724  500000  01-09-2017
# 4   502097814  500000  01-07-2017

# %%
dfTarget.to_csv(r'C:\Users\maitu\Downloads\Target.csv', index=False, header=True)

# %%
dfProduct.head(10)
# Out:
#    ProductKey                    Product  Standard Cost  Color  Subcategory  \
# 0         210  HL Road Frame - Black, 58         868.63  Black  Road Frames
# 1         215    Sport-100 Helmet, Black          12.03  Black      Helmets
# 2         216    Sport-100 Helmet, Black          13.88  Black      Helmets
# 3         217    Sport-100 Helmet, Black          13.09  Black      Helmets
# 4         253  LL Road Frame - Black, 58         176.20  Black  Road Frames
# 5         254  LL Road Frame - Black, 58         170.14  Black  Road Frames
# 6         255  LL Road Frame - Black, 58         204.63  Black  Road Frames
# 7         256  LL Road Frame - Black, 60         176.20  Black  Road Frames
# 8         257  LL Road Frame - Black, 60         170.14  Black  Road Frames
# 9         258  LL Road Frame - Black, 60         204.63  Black  Road Frames
#
#       Category Background Color Format Font Color Format
# 0   Components                 #000000           #FFFFFF
# ...

# %%
dfProduct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ProductKey               397 non-null    int64
#  1   Product                  397 non-null    object
#  2   Standard Cost            397 non-null    float64
#  3   Color                    341 non-null    object
#  4   Subcategory              397 non-null    object
#  5   Category                 397 non-null    object
#  6   Background Color Format  397 non-null    object
#  7   Font Color Format        397 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 24.9+ KB

# %%
dfRegion.head(5)
# Out:
#    SalesTerritoryKey     Region        Country          Group
# 0                  1  Northwest  United States  North America
# 1                  2  Northeast  United States  North America
# 2                  3    Central  United States  North America
# 3                  4  Southwest  United States  North America
# 4                  5  Southeast  United States  North America

# %%
dfSale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57851 entries, 0 to 57850
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SalesOrderNumber   57851 non-null  object
#  1   OrderDate          57851 non-null  object
#  2   ProductKey         57851 non-null  int64
#  3   ResellerKey        57851 non-null  int64
#  4   EmployeeKey        57851 non-null  int64
#  5   SalesTerritoryKey  57851 non-null  int64
#  6   Quantity           57851 non-null  int64
#  7   Unit Price         57851 non-null  float64
#  8   Sales              57851 non-null  float64
#  9   Cost               57851 non-null  float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 4.4+ MB

# %%
dfSale.head(15)
# Out:
#    SalesOrderNumber   OrderDate  ProductKey  ResellerKey  EmployeeKey  \
# 0           SO43897  25-08-2017         235          312          282
# 1           SO43897  25-08-2017         351          312          282
# 2           SO43897  25-08-2017         348          312          282
# 3           SO43897  25-08-2017         232          312          282
# 4           SO44544  18-11-2017         292          312          282
# 5           SO44544  18-11-2017         220          312          282
# 6           SO44544  18-11-2017         351          312          282
# 7           SO44544  18-11-2017         349          312          282
# 8           SO44544  18-11-2017         344          312          282
# 9           SO45321  18-02-2018         346          312          282
# 10          SO45321  18-02-2018         347          312          282
# 11          SO46082  23-05-2018         220          312          282
# ...

# %%
dfSale.head(5)
# Out:
#   SalesOrderNumber   OrderDate  ProductKey  ResellerKey  EmployeeKey  \
# 0          SO43897  25-08-2017         235          312          282
# 1          SO43897  25-08-2017         351          312          282
# 2          SO43897  25-08-2017         348          312          282
# 3          SO43897  25-08-2017         232          312          282
# 4          SO44544  18-11-2017         292          312          282
#
#    SalesTerritoryKey  Quantity  Unit Price    Sales     Cost
# 0                  4         2       28.84    57.68    63.45
# 1                  4         2     2024.99  4049.98  3796.19
# 2                  4         2     2024.99  4049.98  3796.19
# 3                  4         2       28.84    57.68    63.45
# 4                  4         2      818.70  1637.40  1413.62

# %%
dfSale['OrderDate'] = pd.to_datetime(dfSale['OrderDate'])
dfSale['OrderDate']= dfSale['OrderDate'].dt.strftime('%d-%m-%Y')

# %%
dfSale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57851 entries, 0 to 57850
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SalesOrderNumber   57851 non-null  object
#  1   OrderDate          57851 non-null  object
#  2   ProductKey         57851 non-null  int64
#  3   ResellerKey        57851 non-null  int64
#  4   EmployeeKey        57851 non-null  int64
#  5   SalesTerritoryKey  57851 non-null  int64
#  6   Quantity           57851 non-null  int64
#  7   Unit Price         57851 non-null  float64
#  8   Sales              57851 non-null  float64
#  9   Cost               57851 non-null  float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 4.4+ MB

# %%
dfSale.to_csv('Sale.csv', index=False)
dfSale.to_csv(r'C:\Users\maitu\Downloads\Sales.csv', index=False, header=True)

# %%
df3 = pd.merge(dfSale, dfRegion)
df3
# Out:
#       SalesOrderNumber  OrderDate  ProductKey  ResellerKey  EmployeeKey  \
# 0              SO43897 2017-08-25         235          312          282
# 1              SO43897 2017-08-25         351          312          282
# 2              SO43897 2017-08-25         348          312          282
# 3              SO43897 2017-08-25         232          312          282
# 4              SO44544 2017-11-18         292          312          282
# ...                ...        ...         ...          ...          ...
# 57846          SO65191 2020-03-08         225          573          296
# 57847          SO58931 2019-12-04         225          573          296
# 57848          SO65191 2020-03-08         471          573          296
# 57849          SO53485 2019-09-07         471          573          294
# 57850          SO58931 2019-12-04         471          573          296
#
#        SalesTerritoryKey  Quantity  Unit Price    Sales     Cost     Region  \
# ...

# %%
dfSaleByRegion = df3.groupby('Region').agg({'Quantity':'sum','Sales':'sum', 'Cost':'sum'}).reset_index()
dfSaleByRegion
# Out:
#            Region  Quantity        Sales         Cost
# 0       Australia      4055   1391024.85   1471301.62
# 1          Canada     39743  13875632.96  13620056.55
# 2         Central     18619   7633386.86   7468037.62
# 3          France     13903   4527839.69   4522507.53
# 4         Germany      6949   1877743.39   1958740.28
# 5       Northeast     19077   6715354.39   6605755.87
# 6       Northwest     26553  12004822.45  11700586.61
# 7       Southeast     18101   7638606.55   7470110.73
# 8       Southwest     45093  18001116.10  17890365.34
# 9  United Kingdom     12021   3883042.96   3841613.48

# %%
dfSaleByEmployee = pd.merge(pd.merge(dfSale,dfSalesPerson,on='EmployeeKey'),dfTarget,on='EmployeeID')
dfSaleByEmployee.head(5)
# Out:
#   SalesOrderNumber   OrderDate  ProductKey  ResellerKey  EmployeeKey  \
# 0          SO43897  25-08-2017         235          312          282
# 1          SO43897  25-08-2017         235          312          282
# 2          SO43897  25-08-2017         235          312          282
# 3          SO43897  25-08-2017         235          312          282
# 4          SO43897  25-08-2017         235          312          282
#
#    SalesTerritoryKey  Quantity  Unit Price  Sales   Cost  EmployeeID  \
# 0                  4         2       28.84  57.68  63.45   191644724
# 1                  4         2       28.84  57.68  63.45   191644724
# 2                  4         2       28.84  57.68  63.45   191644724
# 3                  4         2       28.84  57.68  63.45   191644724
# 4                  4         2       28.84  57.68  63.45   191644724
#
#       Salesperson                 Title                                UPN  \
# ...

# %%
dfSaleByEmployee = dfSaleByEmployee.groupby('EmployeeID').agg({'Quantity':'sum','Sales':'sum','Target': 'sum'}).reset_index()
dfSaleByEmployee
# Out:
#     EmployeeID  Quantity         Sales        Target
# 0     61161660    377298  1.721369e+08  104738250000
# 1     90836195    253104  1.048421e+08   29925000000
# 2    134219713    491040  1.594573e+08   29964550000
# 3    139397894    806922  3.392924e+08  260766450000
# 4    191644724   1420956  5.485663e+08  279536550000
# 5    234474252    597240  1.882495e+08   74292150000
# 6    399771412    674304  2.657491e+08   78501125000
# 7    481044938     19680  4.178600e+06     732000000
# 8    502097814    159462  5.797714e+07   82282050000
# 9    615389812   1373495  5.170676e+08  102959075000
# 10   668991357    889092  2.915934e+08   86527050000
# 11   716374314    858546  3.767109e+08   69562500000
# 12   758596752     77640  2.920600e+07    3797430000
# 13   841560125   1187352  4.834486e+08  209764100000
# 14   954276278    155208  4.034898e+07    6439125000
# 15   982310417     72324  2.655246e+07   11358800000
# 16   987554265    377568  1.735085e+08   42115250000

# %%
dfProduct['Standard Cost'].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
dfSale['Sales'].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
dfSaleByEmployee.describe()
# Out:
#            Quantity         Sales          Cost
# count     10.000000  1.000000e+01  1.000000e+01
# mean   20411.400000  7.754857e+06  7.654908e+06
# std    13301.916213  5.396132e+06  5.301167e+06
# min     4055.000000  1.391025e+06  1.471302e+06
# 25%    12491.500000  4.044242e+06  4.011837e+06
# 50%    18360.000000  7.174371e+06  7.036897e+06
# 75%    24684.000000  1.091327e+07  1.064297e+07
# max    45093.000000  1.800112e+07  1.789037e+07

# %%
plt.figure(figsize =(12,3))
plt.title('Sale By Region')
plt.xlabel('Region')
plt.ylabel('Sale')

plt.bar(dfSaleByEmployee['Region'], dfSaleByEmployee['Sales'])
plt.show()

# %%
x = np.array(dfSaleByEmployee[('Sales')])
y = np.array(dfSaleByEmployee[('Cost')])
plt.scatter(x, y, color = 'hotpink')
plt.show()

# %%
dfSalesPerson.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmployeeKey  18 non-null     int64
#  1   EmployeeID   18 non-null     int64
#  2   Salesperson  18 non-null     object
#  3   Title        18 non-null     object
#  4   UPN          18 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 852.0+ bytes

# %%
dfSalesPerson.head(5)
# Out:
#    EmployeeKey  EmployeeID     Salesperson                         Title  \
# 0          272   502097814   Stephen Jiang  North American Sales Manager
# 1          277   112432117   Brian Welcker             Director of Sales
# 2          281   841560125  Michael Blythe          Sales Representative
# 3          282   191644724  Linda Mitchell          Sales Representative
# 4          283   615389812  Jillian Carson          Sales Representative
#
#                                  UPN
# 0   stephen-jiang@adventureworks.com
# 1   brian-welcker@adventureworks.com
# 2  michael-blythe@adventureworks.com
# 3  linda-mitchell@adventureworks.com
# 4  jillian-carson@adventureworks.com

# %%
dfSalePersonRegion.head(5)
# Out:
#    EmployeeKey  SalesTerritoryKey
# 0          272                  1
# 1          272                  2
# 2          272                  3
# 3          272                  4
# 4          272                  5

# %%
dfSalePersonRegion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   EmployeeKey        39 non-null     int64
#  1   SalesTerritoryKey  39 non-null     int64
# dtypes: int64(2)
# memory usage: 756.0 bytes
